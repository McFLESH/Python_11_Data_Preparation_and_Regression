# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_11_Data_Preparation_and_Regression/blob/main/11_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Объявите функцию fit_and_predict(). Она должна принимать 4 переменные, которые получаются в результате разделения данных через train_test_split.
# Функция должна обучить модель линейной регрессии на тренировочных данных и на основе тестовых предикторов предсказать значения целевого параметра.


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd


def fit_and_predict(a, b, c, d):
    model = LinearRegression()
    model.fit(a, c)
    result = model.predict(b)
    return result
